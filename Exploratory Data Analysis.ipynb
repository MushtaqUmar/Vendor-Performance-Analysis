# %% [markdown]
# # **Exploratory Data Analysis**
#
# Understanding the dataset to explore how the data is present in the database and if there is a need of creating some aggregated tables that can help with:
#
# * Vendor selection for profitability
# * Product Pricing Optimization
# * Inventory management

# %%
import pandas as pd
import numpy as np
import mysql.connector

# %%
# ================ Connect to MySQL Local Server DB -> To RUN MYSQL QUERIES USING : mysql.connector + cursor ===========
conn = mysql.connector.connect(
    host='localhost',
    user='root',
    password='UMMU@112244',
    database='inventory_db'
)


# ============ cursor (DB object to run mysql queries and fetch data line by line from databale tables as per reqd) ===========
cursor = conn.cursor()

# %%
from sqlalchemy import create_engine   # create_engine Used to connect Python to MySQL databases using SQLAlchemy(-SQLAlchemy is a powerful Python library that lets you connect to databases and run SQL queries using both raw SQL and Pythonic ORM-style code.).
from sqlalchemy.engine import URL   # URL is a special helper class in SQLAlchemy used to safely and correctly build database connection strings — especially when your password or other parts contain special characters (like @, :, #, etc.).


# ================== Connet to MySQL local server -> Use SQLAlchemy instead (Recommended -> if you want use pandas for sql queries to run )
url = URL.create(   
        drivername="mysql+mysqlconnector",
        username="root",
        password="UMMU@112244",  # Don't worry, it's safe here
        host="localhost",
        database="Inventory_db"
    )

engine = create_engine(url)  # Connected now

# %%
#=============== SEPERATE SCRIPT TO INGEST DATA INTO DATABASE ==============
# %run ingestion_db.py  # Calling th at

# %% [markdown]
# #### ============ Tables we have in hand =============

# %%
tables = pd.read_sql("SHOW TABLES", conn)   # Check tables at database (Here done using pandas to run sql query) 
tables

# ============= Ways to for NO WARNING =================================

# WAY 1 : Using raw mysql.connector + cursor  ===============
# cursor.execute("SHOW TABLES")

# for table in cursor.fetchall():
#     print(table[0])



# WAY 2: Use SQLAlchemy instead (Recommended -> if you want use pandas for sql queries to run ) ====
# from sqlalchemy import create_engine
# import pandas as pd

# engine = create_engine("mysql+mysqlconnector://root:your_password@localhost/inventory_db")

# with engine.connect() as conn:
#     tables = pd.read_sql("SHOW TABLES", conn)
# print(tables)
# Out:
# C:\Users\umarm\AppData\Local\Temp\ipykernel_13096\3942794502.py:1: UserWarning: pandas only supports SQLAlchemy connectable (engine/connection) or database string URI or sqlite3 DBAPI2 connection. Other DBAPI2 objects are not tested. Please consider using SQLAlchemy.
#   tables = pd.read_sql("SHOW TABLES", conn)   # Check tables at database (Here done using pandas to run sql query)
#   Tables_in_inventory_db
# 0        begin_inventory
# 1          end_inventory
# 2        purchase_prices
# 3              purchases
# 4                  sales
# 5         vendor_invoice
# 6  vendors_final_summary

# %%
# Get idea what type of data is present in each table.

with engine.connect() as conn:        # RUN SQL (MySQL server through sqlalchemy) QUERIES   
    for table in tables['Tables_in_inventory_db']: # Why we did tables['Tables_in_inventory_db']? -> print(tables) above and see result , you will get this know 
        print('-'*50, f'{table}', '-'*50)
        print('Count of records:', pd.read_sql(f"SELECT COUNT(*) AS count FROM {table}", conn)['count'].values[0])   # Get only actual count (no datatype, or column name of returned result/df  as uery result)
        display(pd.read_sql(f"SELECT * FROM {table} limit 5", conn) )   # First 5 records just to check what we have.

# pandas.display() :- Renders the rich (HTML) representation of an object (Mostly used in jupyter notebook for pandas  Dataframe, plots, images)
# pandas.print() :-Prints a textual string representation of an object  (Standard python way to show output)
# Out:
# -------------------------------------------------- begin_inventory --------------------------------------------------
# Count of records: 206529
#          InventoryId  Store          City  Brand                  Description  \
# 0  1_HARDERSFIELD_58      1  HARDERSFIELD     58  Gekkeikan Black & Gold Sake
# 1  1_HARDERSFIELD_60      1  HARDERSFIELD     60       Canadian Club 1858 VAP
# 2  1_HARDERSFIELD_62      1  HARDERSFIELD     62     Herradura Silver Tequila
# 3  1_HARDERSFIELD_63      1  HARDERSFIELD     63   Herradura Reposado Tequila
# 4  1_HARDERSFIELD_72      1  HARDERSFIELD     72         No. 3 London Dry Gin
#
#     Size  onHand  Price   startDate
# 0  750mL       8  12.99  2024-01-01
# 1  750mL       7  10.99  2024-01-01
# 2  750mL       6  36.99  2024-01-01
# 3  750mL       3  38.99  2024-01-01
# 4  750mL       6  34.99  2024-01-01
# -------------------------------------------------- end_inventory --------------------------------------------------
# ...

# %% [markdown]
# ###  ***Major Insights After Exploring tables:***
# ##### 1) begin_inventory & start_inventory are not much related to out business problem.
# * Reason: Nothing about vendors given and only january & December inventory related info is given
# ##### 2) Everything in purchase_prices is already included in purchases for brands and stores of vendors.
# ##### 3) Ppurchases and sales tables aare important consoiderations for our business problems.
# * purchases : About purchases made by vendors.
# * sales : About sales made by vendors
# ##### 4) vendor_invoice : Important since about vendors we have data given in it.
# * purchases -> Gives bill of purchases made by vendors with detail of store, product/brand, price etc.
# * vendor_invoice -> Gives same bill but overall (Not in detail where & where purchases has been made)
#
# #### ***Remark: Our business problem related tables are : purchases, sales and vendor_invoice***

# %% [markdown]
# # **==================== Extracting tables (as df with name as tables) so that we can uses them whenever needed.**====================**

# %%
# with engine.connect() as conn:
#     begin_inventory= pd.read_sql_query("SELECT * FROM begin_inventory", conn)
#     display(begin_inventory)
# Out:
#                InventoryId  Store          City  Brand  \
# 0        1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1        1_HARDERSFIELD_60      1  HARDERSFIELD     60
# 2        1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 3        1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 4        1_HARDERSFIELD_72      1  HARDERSFIELD     72
# ...                    ...    ...           ...    ...
# 206524  79_BALLYMENA_46985     79     BALLYMENA  46985
# 206525  79_BALLYMENA_47014     79     BALLYMENA  47014
# 206526  79_BALLYMENA_47090     79     BALLYMENA  47090
# 206527  79_BALLYMENA_90011     79     BALLYMENA  90011
# 206528  79_BALLYMENA_90089     79     BALLYMENA  90089
#
#                          Description   Size  onHand   Price   startDate
# 0        Gekkeikan Black & Gold Sake  750mL       8   12.99  2024-01-01
# 1             Canadian Club 1858 VAP  750mL       7   10.99  2024-01-01
# 2           Herradura Silver Tequila  750mL       6   36.99  2024-01-01
# ...

# %%
# with engine.connect() as conn:
#     end_inventory= pd.read_sql_query("SELECT * FROM end_inventory", conn)
#     display(end_inventory)
# Out:
#               InventoryId  Store          City  Brand  \
# 0       1_HARDERSFIELD_58      1  HARDERSFIELD     58
# 1       1_HARDERSFIELD_62      1  HARDERSFIELD     62
# 2       1_HARDERSFIELD_63      1  HARDERSFIELD     63
# 3       1_HARDERSFIELD_72      1  HARDERSFIELD     72
# 4       1_HARDERSFIELD_75      1  HARDERSFIELD     75
# ...                   ...    ...           ...    ...
# 224484  81_PEMBROKE_90087     81      PEMBROKE  90087
# 224485  81_PEMBROKE_90088     81      PEMBROKE  90088
# 224486  81_PEMBROKE_90089     81      PEMBROKE  90089
# 224487  81_PEMBROKE_90090     81      PEMBROKE  90090
# 224488  81_PEMBROKE_90604     81      PEMBROKE  90604
#
#                          Description   Size  onHand   Price     endDate
# 0        Gekkeikan Black & Gold Sake  750mL      11   12.99  2024-12-31
# 1           Herradura Silver Tequila  750mL       7   36.99  2024-12-31
# 2         Herradura Reposado Tequila  750mL       7   38.99  2024-12-31
# ...

# %%
# with engine.connect() as conn:
#     purchase_prices= pd.read_sql_query("SELECT * FROM purchase_prices", conn)
#     display(purchase_prices)
# Out:
#        Brand                   Description  Price    Size Volume  \
# 0         58   Gekkeikan Black & Gold Sake  12.99   750mL    750
# 1         62      Herradura Silver Tequila  36.99   750mL    750
# 2         63    Herradura Reposado Tequila  38.99   750mL    750
# 3         72          No. 3 London Dry Gin  34.99   750mL    750
# 4         75     Three Olives Tomato Vodka  14.99   750mL    750
# ...      ...                           ...    ...     ...    ...
# 12256  44917     Ferreira 10-Yr Tawny Port  24.99   750mL    750
# 12257  44944     Sanford Santa Rita Pnt Nr  22.99   750mL    750
# 12258  45016  Neal One Lane Bridg Cab Svgn  93.99   750mL    750
# 12259  46011       Folonari Pnt Nr Venezie  12.99  1500ml   1500
# 12260  46964     Calera Viognier Mt Harlan  35.99   750mL    750
#
#        Classification  PurchasePrice  VendorNumber  \
# 0                   1           9.28          8320
# 1                   1          28.67          1128
# ...

# %%
# with engine.connect() as conn:
#     purchases= pd.read_sql_query("SELECT * FROM purchases", conn)
#     display(purchases)
# Out:
#                   InventoryId  Store  Brand                   Description  \
# 0           69_MOUNTMEND_8412     69   8412     Tequila Ocho Plata Fresno
# 1            30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide
# 2           34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced
# 3         1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide
# 4           76_DONCASTER_2034     76   2034     Glendalough Double Barrel
# ...                       ...    ...    ...                           ...
# 2372469     49_GARIGILL_22298     49  22298       Zorvino Vyds Sangiovese
# 2372470  1_HARDERSFIELD_19556      1  19556    Zorvino Bacca Z Blackberry
# 2372471   66_EANVERNESS_22297     66  22297            Zorvino Vyds Pearz
# 2372472    69_MOUNTMEND_19557     69  19557  Zorvino Fragole Z Strawberry
# 2372473    55_DRY GULCH_22298     55  22298       Zorvino Vyds Sangiovese
#
#           Size  VendorNumber                   VendorName  PONumber  \
# ...

# %%
# with engine.connect() as conn:
#     sales= pd.read_sql_query("SELECT * FROM sales", conn)

# %%
display(sales)
# Out:
#                   InventoryId  Store  Brand                 Description  \
# 0         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 1         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 2         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 3         1_HARDERSFIELD_1004      1   1004  Jim Beam w/2 Rocks Glasses
# 4         1_HARDERSFIELD_1005      1   1005     Maker's Mark Combo Pack
# ...                       ...    ...    ...                         ...
# 11365777    76_DONCASTER_5403     76   5403           Amaretto di Amore
# 11365778    76_DONCASTER_5403     76   5403           Amaretto di Amore
# 11365779    76_DONCASTER_5403     76   5403           Amaretto di Amore
# 11365780    76_DONCASTER_5403     76   5403           Amaretto di Amore
# 11365781    76_DONCASTER_5403     76   5403           Amaretto di Amore
#
#                 Size  SalesQuantity  SalesDollars  SalesPrice   SalesDate  \
# ...

# %%
# with engine.connect() as conn:
#     vendor_invoice= pd.read_sql_query("SELECT * FROM vendor_invoice", conn)
#     display(vendor_invoice)
# Out:
#       VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0              105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1             4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 2              388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169
# 3              480  BACARDI USA INC              2024-01-12      8106
# 4              516  BANFI PRODUCTS CORP          2024-01-07      8170
# ...            ...                          ...         ...       ...
# 5538          9622  WEIN BAUER INC               2025-01-06     13626
# 5539          9625  WESTERN SPIRITS BEVERAGE CO  2025-01-10     13661
# 5540          3664  WILLIAM GRANT & SONS INC     2025-01-02     13643
# 5541          9815  WINE GROUP INC               2025-01-03     13602
# 5542         90058  ZORVINO VINEYARDS            2025-01-05     13574
#
#           PODate     PayDate  Quantity    Dollars  Freight Approval
# ...

# %% [markdown]
# # **=============Exploring tables in detail that are important to us (i.e., 4 tables: purchases, purchase_prices, sales and vendor_invoice )================**

# %%
#==== COnsidering any vendor and explore what we have in data

# %%
with engine.connect() as conn:
    purchase_price_1= pd.read_sql_query("SELECT * FROM purchase_prices WHERE VendorNumber = 4466", conn)
purchase_price_1
# Out:
#    Brand                   Description  Price    Size Volume  Classification  \
# 0   5215  TGI Fridays Long Island Iced  12.99  1750mL   1750               1
# 1   5255  TGI Fridays Ultimte Mudslide  12.99  1750mL   1750               1
# 2   3140      TGI Fridays Orange Dream  14.99  1750mL   1750               1
#
#    PurchasePrice  VendorNumber                   VendorName
# 0           9.41          4466  AMERICAN VINTAGE BEVERAGE
# 1           9.35          4466  AMERICAN VINTAGE BEVERAGE
# 2          11.19          4466  AMERICAN VINTAGE BEVERAGE

# %%
# Consider any vendor and explore table what is given above in tables....
with engine.connect() as conn:
    purchases_1 = pd.read_sql_query("SELECT * FROM purchases WHERE VendorNumber = 4466", conn)
purchases_1
# Out:
#               InventoryId  Store  Brand                   Description   Size  \
# 0        30_CULCHETH_5255     30   5255  TGI Fridays Ultimte Mudslide  1.75L
# 1       34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2     1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 3       38_GOULCREST_5215     38   5215  TGI Fridays Long Island Iced  1.75L
# 4     59_CLAETHORPES_5215     59   5215  TGI Fridays Long Island Iced  1.75L
# ...                   ...    ...    ...                           ...    ...
# 2187     81_PEMBROKE_5215     81   5215  TGI Fridays Long Island Iced  1.75L
# 2188   62_KILMARNOCK_5255     62   5255  TGI Fridays Ultimte Mudslide  1.75L
# 2189    34_PITMERDEN_5215     34   5215  TGI Fridays Long Island Iced  1.75L
# 2190     6_GOULCREST_5215      6   5215  TGI Fridays Long Island Iced  1.75L
# 2191    35_HALIVAARA_5255     35   5255  TGI Fridays Ultimte Mudslide  1.75L
#
# ...

# %%
# Insight -> Vendors have made multiple purchases on different dates

# %%
with engine.connect() as conn:
    sales_1 = pd.read_sql_query("SELECT * FROM sales WHERE VendorNo = 4466", conn)
sales_1.head(30)
# Out:
#             InventoryId  Store  Brand                   Description   Size  \
# 0   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 1   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 2   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 3   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 4   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 5   1_HARDERSFIELD_5215      1   5215  TGI Fridays Long Island Iced  1.75L
# 6   1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 7   1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 8   1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 9   1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# 10  1_HARDERSFIELD_5255      1   5255  TGI Fridays Ultimte Mudslide  1.75L
# ...

# %%
with engine.connect() as conn:
    vendor_invoice_1 = pd.read_sql("SELECT * FROM vendor_invoice WHERE VendorNumber = 4466", conn)
vendor_invoice_1
# Out:
#     VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 1           4466  AMERICAN VINTAGE BEVERAGE    2024-01-19      8207
# 2           4466  AMERICAN VINTAGE BEVERAGE    2024-01-18      8307
# 3           4466  AMERICAN VINTAGE BEVERAGE    2024-01-27      8469
# 4           4466  AMERICAN VINTAGE BEVERAGE    2024-02-04      8532
# 5           4466  AMERICAN VINTAGE BEVERAGE    2024-02-09      8604
# 6           4466  AMERICAN VINTAGE BEVERAGE    2024-02-17      8793
# 7           4466  AMERICAN VINTAGE BEVERAGE    2024-03-01      8892
# 8           4466  AMERICAN VINTAGE BEVERAGE    2024-03-07      8995
# 9           4466  AMERICAN VINTAGE BEVERAGE    2024-03-12      9033
# 10          4466  AMERICAN VINTAGE BEVERAGE    2024-03-16      9180
# 11          4466  AMERICAN VINTAGE BEVERAGE    2024-03-23      9244
# 12          4466  AMERICAN VINTAGE BEVERAGE    2024-03-31      9371
# ...

# %%
# Slight difference between purchase_prices and purchases:
purchases_1.groupby(['Brand', 'PurchasePrice'])[['Quantity','Dollars']].sum().reset_index()   # reset_index will bring Brand , PurchasePrice as columns (instead of  index made when grouped by default) i.e,  reset the index of your grouped DataFrame
# Out:
#    Brand  PurchasePrice  Quantity   Dollars
# 0   3140          11.19      4640  51921.60
# 1   5215           9.41      4923  46325.43
# 2   5255           9.35      6215  58110.25

# %%
sales_1.groupby('Brand')[['SalesPrice','SalesQuantity','SalesDollars']].sum()
# Out:
#        SalesPrice  SalesQuantity  SalesDollars
# Brand
# 3140     26213.82           3510      45594.90
# 5215     36943.56           4173      54207.27
# 5255     44997.36           5384      69938.16

# %% [markdown]
# ##  Insights...
# ##### 1 + 2) begin_inventory, end_inventory tables:- We have inventory information given for year 2024 from january to december.
# ##### 2+3) Slight difference between purchase_prices and purchases:
# * purchases_prices -> Tells from which brands vendor has made purchase.
# * purchases -> Gives detail of purchases like quantity purchased, From which Store, detailed Dates etc.
# ##### (3+4) Slight difference between purchases and vendor_invoice tables:
# * purchases -> Also gives bill details of purchases made by vendors with a detail of from which brand and store inventory has been made.
# * vendor_invoice -> Gives same bill but overall (Not in detail like from 'where & where' purchases has been made etc)
# ##### 5) sales tables -> Detail about sales made by vendors.
#
# ### ***Remark: sales and purchases tables gives actual purformance shown by vendors***

# %% [markdown]
# **Moreover**
# * The purchases table contains actual purchase data, including the date of purchase, products (brands) purchased by vendors, the amount paid (in dollars), and the quantity purchased.
# * The purchase price column is derived from the purchase_prices table, which provides product-wise actual and purchase prices. The combination of vendor and brand is unique in this table.
# * The vendor_invoice table aggregates data from the purchases table, summarizing quantity and dollar amounts, along with an additional column for freight. This table maintains uniqueness based on vendor and PO number.
# * The sales table captures actual sales transactions, detailing the brands purchased by vendors, the quantity sold, the selling price, and the revenue earned.

# %% [markdown]
# # **BOOKMARK
# # **-----------------------------------------------------------------------------------------FROM HERE TILL END** -> WE HAVE WRITTEN EVERY IN SEPERATE SCRIPT THAT WE CAN SCHEDULE FOR REPETETIVE AS DATA COMES FROM SERVER IN REAL COMPANY -----------------------------------------------------------------------------------------
#
# ### Run below cells if you want to explore how we did that directly

# %% [markdown]
# ## ======================== **As the data that we need for analysis is distributed in different tables, we need to create a summary table containing:=======================**
#
# * -purchase transactions made by vendors
# * -sales transaction data
# * -freight costs for each vendor (cost of transporting goods from the seller (or vendor) to the buyer’s location like buyer's store/warehouse).
# * -actual product prices from vendors

# %%
#============= Summary from vendor_invoice required to us
# vendor_invoice.head(5)
# Out:
#    VendorNumber                   VendorName InvoiceDate  PONumber  \
# 0           105  ALTAMAR BRANDS LLC           2024-01-04      8124
# 1          4466  AMERICAN VINTAGE BEVERAGE    2024-01-07      8137
# 2           388  ATLANTIC IMPORTING COMPANY   2024-01-09      8169
# 3           480  BACARDI USA INC              2024-01-12      8106
# 4           516  BANFI PRODUCTS CORP          2024-01-07      8170
#
#        PODate     PayDate  Quantity    Dollars  Freight Approval
# 0  2023-12-21  2024-02-16         6     214.26     3.47     None
# 1  2023-12-22  2024-02-21        15     140.55     8.57     None
# 2  2023-12-24  2024-02-16         5     106.60     4.61     None
# 3  2023-12-20  2024-02-05     10100  137483.78  2935.20     None
# 4  2023-12-24  2024-02-12      1935   15527.25   429.20     None

# %%
# with engine.connect() as conn:
#     freight_summary = pd.read_sql("""SELECT VendorNumber, SUM(Freight) as FreightCost
#     FROM vendor_invoice
#     GROUP BY VendorNumber""", conn)      # Check freightCost for each of 126 vendors(VendorName or VendorNumber as per you choice) who sells products(here called brand)

# display(freight_summary)
# Out:
#      VendorNumber  FreightCost
# 0             105        62.39
# 1            4466       793.91
# 2             388       211.74
# 3             480     89286.27
# 4             516      8510.41
# ..            ...          ...
# 121        201359         0.09
# 122          4901         0.72
# 123         90059        74.84
# 124          5083        10.68
# 125            54         0.48
#
# [126 rows x 2 columns]

# %%
#========== Summary From purchase_prices and purchases required fields
# with engine.connect() as conn:
#     Purchase_PurPrice_summary = pd.read_sql("""SELECT 
#     p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice,
#     pp.Volume, pp.Price AS ActualPrice,
#     SUM(p.Quantity) AS TotalPurchaseQuantity,
#     SUM(p.Dollars) AS TotalPurchaseDollars
#     FROM purchases AS p
#     INNER JOIN purchase_prices AS pp
#     ON p.Brand = pp.Brand 
#     WHERE p.PurchasePrice > 0  # Need those having price (No free i.e., no mistakenly added records)
#     GROUP BY  p.VendorNumber, p.VendorName, p.Brand,p.Description, p.PurchasePrice, pp.Volume, pp.Price
#     ORDER BY TotalPurchaseDollars""", conn)

# display(Purchase_PurPrice_summary)
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              7245  PROXIMO SPIRITS INC.          3065
# 1              3960  DIAGEO NORTH AMERICA INC      6127
# 2              3924  HEAVEN HILL DISTILLERIES      9123
# 3              8004  SAZERAC CO INC                5683
# 4              9815  WINE GROUP INC                8527
# ...             ...                          ...    ...
# 10687          3960  DIAGEO NORTH AMERICA INC      3545
# 10688          3960  DIAGEO NORTH AMERICA INC      4261
# 10689         17035  PERNOD RICARD USA             8068
# 10690          4425        MARTIGNETTI COMPANIES   3405
# 10691          1128  BROWN-FORMAN CORP             1233
#
#                        Description  PurchasePrice Volume  ActualPrice  \
# 0         Three Olives Grape Vodka           0.71     50         0.99
# 1      The Club Strawbry Margarita           1.47    200         1.99
# 2                  Deep Eddy Vodka           0.74     50         0.99
# ...

# %%
# #========== Summar From sales table required
# sales.columns

# %%
# with engine.connect() as conn:
#     sales_summary = pd.read_sql_query("""SELECT
#     VendorNo, Brand, 
#     SUM(SalesQuantity) AS TotalSalesQuantity,
#     SUM(SalesPrice) AS TotalSalesPrice,
#     SUM(SalesDollars) AS TotalSalesDollars,
#     SUM(ExciseTax) AS TotalExciseTax 
#     FROM sales
#     GROUP BY VendorNo, Brand
#     ORDER BY TotalSalesDollars""", conn)   
#  # ExciseTax: levied by the government on specific goods or services, often added before the product is sold to customers (often include in price)

# %%
# sales_summary
# Out:
#        VendorNo  Brand  TotalSalesQuantity  TotalSalesPrice  \
# 0          8004   5287                 2.0             0.98
# 1          9206   2773                 1.0             0.99
# 2          3252   3933                 2.0             0.99
# 3         10050   3623                 2.0             1.98
# 4           660   2134                 1.0             2.49
# ...         ...    ...                 ...              ...
# 11067      3960   3545            121484.0        496084.85
# 11068      3960   4261            169057.0        382729.79
# 11069     17035   8068            169835.0        420408.49
# 11070      4425   3405            142035.0        512403.31
# 11071      1128   1233            128606.0        613021.40
#
#        TotalSalesDollars  TotalExciseTax
# 0                   0.98            0.10
# 1                   0.99            0.05
# 2                   1.98            0.10
# 3                   1.98            0.10
# ...

# %% [markdown]
# # Bringing All required summary tables under common tables for an amazing and easy insights and recommendations

# %%
# ========================== The following query DOES NOT RUN because it is very large since it has to fetch data from multiple tables which are huge in size,
# ===================  SO QUERY OPTIMIZATION IS VERY IMPORTANT HERE

# import time   # Let's check how much it takle to combine them
# start = time.time()

# with engine.connect() as conn:
#     final_table = pd.read_sql("""SELECT pp.VendorNumber, pp.Brand, pp.PurchasePrice, pp.Price AS ActualPrice,   # ======= pp i.e., purchases_prices already contain aggregates (Details are in purchases table so no need to consider that) 
#     SUM(vi.Quantity) AS TotalPurchaseQuantity,    # vendor_invoice contains aggregates like quantity purchased, Dollars (Its details are in purchases table , so again no need to consider that)
#     SUM(vi.Dollars) AS TotalPurchaseDollars,
#     SUM(s.SalesPrice) AS TotalSalesPrice,
#     SUM(s.ExciseTax) AS TotalExciseTax,
#     SUM(s.SalesQuantity) AS TotalSalesQuantity,
#     SUM(s.SalesDollars) AS TotalSalesDollars,
#     SUM(vi.Freight) AS TotalFreightCost
    
#     FROM purchase_prices AS pp
#     INNER JOIN
#     sales AS s
#     ON pp.VendorNumber = s.VendorNo
#     AND pp.Brand = s.Brand
    
#     INNER JOIN 
#     vendor_invoice AS vi
#     ON pp.VendorNumber = vi.VendorNumber
#     GROUP BY  pp.VendorNumber, pp.Brand, pp.PurchasePrice, pp.Price """, conn)

# end = time.time()

# print("Total Time : ", (end-start)/60,"min")

# %%
# =============== OPtimizing query .... (sales table creates more issue bcz it has data in crores) -> So let's use subquery or CTE(Common table expresion)
# import time
# start = time.time()

# with engine.connect() as conn:
#     vendors_final_summary =  pd.read_sql_query("""WITH FreightSummary AS(
#     SELECT VendorNumber, SUM(Freight) as FreightCost
#     FROM vendor_invoice
#     GROUP BY VendorNumber
#     ),
    
#     PurchaseSummary AS (SELECT 
#     p.VendorNumber, p.VendorName, p.Brand, p.Description, p.PurchasePrice,
#     pp.Price AS ActualPrice, pp.Volume,
#     SUM(p.Quantity) AS TotalPurchaseQuantity,
#     SUM(p.Dollars) AS TotalPurchaseDollars
#     FROM purchases AS p
#     INNER JOIN purchase_prices AS pp
#     ON p.Brand = pp.Brand 
#     WHERE p.PurchasePrice > 0  # Need those having price (No free i.e., no mistakenly added records)
#     GROUP BY  p.VendorNumber, p.VendorName, p.Brand,p.Description, p.PurchasePrice, pp.Volume, pp.Price
#     ),

#     SalesSummary AS (SELECT
#     VendorNo, Brand, 
#     SUM(SalesQuantity) AS TotalSalesQuantity,
#     SUM(SalesPrice) AS TotalSalesPrice,
#     SUM(SalesDollars) AS TotalSalesDollars,
#     SUM(ExciseTax) AS TotalExciseTax 
#     FROM sales
#     GROUP BY VendorNo, Brand
#     )

#     # Now fetch final summarey table from above CTE
#     SELECT 
#     ps.VendorNumber, ps.VendorName, ps.Brand, ps.Description, ps.PurchasePrice,
#     ps.Volume, ps.ActualPrice,
#     ps.TotalPurchaseQuantity,
#     ps.TotalPurchaseDollars,
#     ss.TotalSalesQuantity,
#     ss.TotalSalesPrice,
#     ss.TotalSalesDollars,
#     ss.TotalExciseTax,
#     fs.FreightCost
#     FROM PurchaseSummary AS ps
#     LEFT JOIN SalesSummary AS ss     # Left joinso that we can't skip those who have purchased products but have not sold anything yet.
#     ON ps.VendorNumber = ss.VendorNo
#     AND ps.Brand = ss.Brand
#     LEFT JOIN FreightSummary AS fs
#     ON ps.VendorNumber = fs.VendorNumber
#     ORDER BY ps.TotalPurchaseDollars DESC""", conn)
       
# end = time.time()
# print("Total Time : ", (end-start)/60,"min")
# Out:
# Total Time :  0.7856790542602539 min

# %%
# display(vendors_final_summary)
# Out:
#        VendorNumber                   VendorName  Brand  \
# 0              1128  BROWN-FORMAN CORP             1233
# 1              4425        MARTIGNETTI COMPANIES   3405
# 2             17035  PERNOD RICARD USA             8068
# 3              3960  DIAGEO NORTH AMERICA INC      4261
# 4              3960  DIAGEO NORTH AMERICA INC      3545
# ...             ...                          ...    ...
# 10687          9815  WINE GROUP INC                8527
# 10688          8004  SAZERAC CO INC                5683
# 10689          3924  HEAVEN HILL DISTILLERIES      9123
# 10690          3960  DIAGEO NORTH AMERICA INC      6127
# 10691          7245  PROXIMO SPIRITS INC.          3065
#
#                        Description  PurchasePrice Volume  ActualPrice  \
# 0          Jack Daniels No 7 Black          26.27   1750        36.99
# 1            Tito's Handmade Vodka          23.19   1750        28.99
# 2                 Absolut 80 Proof          18.24   1750        24.99
# ...

# %% [markdown]
# # ***INSIGHTS...***
#
# #### **The above query generates a vendor-wise sales and purchase summary, which is valuable for:**
#
# ##### **Performance Optimization:**
# * The query involves heavy joins and aggregations on large datasets like sales and purchases.
# * Storing the pre-aggregated results avoids repeated expensive computations (CTE's)
# * Helps in analyzing sales, purchases, and pricing for different vendors and brands.
# * Future Benefits of Storing this data for faster Dashboarding & Reporting (By creatig its seperate script and scheduling to reduce manual work and do dashboarding directly on summary data).
# * Instead of running expensive queries each time, dashboards can fetch data quickly from vendor_final_summary.

# %% [markdown]
# # ***====================== Pushing/Saving this final table into mysql local server DB 'Inventory_db" so that we don't need to run above query to perform any calculation, rather get this data from server itself.====================***

# %% [markdown]
# # Before saving into database, let's do ***DATA CLEANING*** (Handling Missing Values,Correcting Inconsistent Formats, Duplicate handling, Fixing Typos and Entry Errors, Standardizing Units ...

# %%
# # Check datatypes
# vendors_final_summary.dtypes
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# Volume                    object
# ActualPrice              float64
# TotalPurchaseQuantity    float64
# TotalPurchaseDollars     float64
# TotalSalesQuantity       float64
# TotalSalesPrice          float64
# TotalSalesDollars        float64
# TotalExciseTax           float64
# FreightCost              float64
# dtype: object

# %% [markdown]
# * **Insight -> Alright but need to change Volume's datatype from object to float**

# %%
# vendors_final_summary['Volume'] = vendors_final_summary['Volume'].astype('float64')

# %%
# #=============== Check null entries/missing
# vendors_final_summary.isnull().sum()
# Out:
# VendorNumber               0
# VendorName                 0
# Brand                      0
# Description                0
# PurchasePrice              0
# Volume                     0
# ActualPrice                0
# TotalPurchaseQuantity      0
# TotalPurchaseDollars       0
# TotalSalesQuantity       375
# TotalSalesPrice          375
# TotalSalesDollars        375
# TotalExciseTax           375
# FreightCost                0
# dtype: int64

# %%
# # Fillinng null with 0 (nothing sold)
# vendors_final_summary.fillna(0, inplace=True)

# %% [markdown]
# * **Insight -> Some vendors have sales entries as NULL , means they have purchased product/brand but not yet sold anything**

# %%
# #====== Check for Categorical columns like VendorName,Description
# vendors_final_summary['VendorName'].tolist()

# %% [markdown]
# * **Insight -> Irrelevant white spaces specially trailing spaces**

# %%
# Fix this
# vendors_final_summary['VendorName'] = vendors_final_summary['VendorName'].str.strip()  # strip() will trim spaces

# %%
# vendors_final_summary['Description'].unique()b
# Out:
# array(['Jack Daniels No 7 Black', "Tito's Handmade Vodka",
#        'Absolut 80 Proof', ..., 'Crown Royal Apple',
#        'Concannon Glen Ellen Wh Zin', 'The Club Strawbry Margarita'],
#       dtype=object)

# %% [markdown]
# * **Insight -> Description is Alright**

# %% [markdown]
# # =============== ***Data Wrangling*** (its sub-part of data cleaning) i.e, feature engineering (new featutures), joining/merging if any, data transformation etc =================

# %% [markdown]
# #==== New features that help to get more related insights about our business problem

# %%
# vendors_final_summary.columns
# Out:
# Index(['VendorNumber', 'VendorName', 'Brand', 'Description', 'PurchasePrice',
#        'Volume', 'ActualPrice', 'TotalPurchaseQuantity',
#        'TotalPurchaseDollars', 'TotalSalesQuantity', 'TotalSalesPrice',
#        'TotalSalesDollars', 'TotalExciseTax', 'FreightCost'],
#       dtype='object')

# %%
# vendors_final_summary['GrossProfit'] = vendors_final_summary['TotalSalesDollars'] - vendors_final_summary['TotalPurchaseDollars']   # Negative means LOss
# vendors_final_summary.head()
# Out:
#    VendorNumber                VendorName  Brand              Description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    PurchasePrice  Volume  ActualPrice  TotalPurchaseQuantity  \
# 0          26.27  1750.0        36.99               145080.0
# 1          23.19  1750.0        28.99               164038.0
# 2          18.24  1750.0        24.99               187407.0
# 3          16.17  1750.0        22.99               201682.0
# 4          21.89  1750.0        29.99               138109.0
#
#    TotalPurchaseDollars  TotalSalesQuantity  TotalSalesPrice  \
# 0            3811251.60            128606.0        613021.40
# ...

# %%
#  #======= Profit Margin of vendors (%)
# vendors_final_summary['ProfitMargin'] = round(vendors_final_summary['GrossProfit'] / vendors_final_summary['TotalSalesDollars'] * 100, 2)   # Negative means LOss
# # It may have infinity since TotalSalesDollars in denomenator is 0 for some vendors - Handling it 

# # Replace inf, -inf with 0
# vendors_final_summary['ProfitMargin'] = vendors_final_summary['ProfitMargin'].replace([np.inf, -np.inf], 0)
# vendors_final_summary.head()
# Out:
#    VendorNumber                VendorName  Brand              Description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    PurchasePrice  Volume  ActualPrice  TotalPurchaseQuantity  \
# 0          26.27  1750.0        36.99               145080.0
# 1          23.19  1750.0        28.99               164038.0
# 2          18.24  1750.0        24.99               187407.0
# 3          16.17  1750.0        22.99               201682.0
# 4          21.89  1750.0        29.99               138109.0
#
#    TotalPurchaseDollars  TotalSalesQuantity  TotalSalesPrice  \
# 0            3811251.60            128606.0        613021.40
# ...

# %%
# # ========= Column for 'StockTurnOver' : (or Inventory Turnover)It is a rate at which a company sells and replaces its inventory over a specific period, typically a year
# vendors_final_summary['StockTurnover'] = round(vendors_final_summary['TotalSalesQuantity'] / vendors_final_summary['TotalPurchaseQuantity'], 2) # Mosttly <= 1 (if > 1, means company has old quantities pending and sold that as well)
# vendors_final_summary.head()
# Out:
#    VendorNumber                VendorName  Brand              Description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    PurchasePrice  Volume  ActualPrice  TotalPurchaseQuantity  \
# 0          26.27  1750.0        36.99               145080.0
# 1          23.19  1750.0        28.99               164038.0
# 2          18.24  1750.0        24.99               187407.0
# 3          16.17  1750.0        22.99               201682.0
# 4          21.89  1750.0        29.99               138109.0
#
#    TotalPurchaseDollars  TotalSalesQuantity  TotalSalesPrice  \
# 0            3811251.60            128606.0        613021.40
# ...

# %%
# # Sales to Purchase Ratio:  It tells how much you are getting on selling compared to how much you are inventing on buying.
# vendors_final_summary['SalesToPurchaseRatio'] = vendors_final_summary['TotalSalesDollars'] / vendors_final_summary['TotalPurchaseDollars']
# vendors_final_summary.head()
# Out:
#    VendorNumber                VendorName  Brand              Description  \
# 0          1128         BROWN-FORMAN CORP   1233  Jack Daniels No 7 Black
# 1          4425     MARTIGNETTI COMPANIES   3405    Tito's Handmade Vodka
# 2         17035         PERNOD RICARD USA   8068         Absolut 80 Proof
# 3          3960  DIAGEO NORTH AMERICA INC   4261   Capt Morgan Spiced Rum
# 4          3960  DIAGEO NORTH AMERICA INC   3545          Ketel One Vodka
#
#    PurchasePrice  Volume  ActualPrice  TotalPurchaseQuantity  \
# 0          26.27  1750.0        36.99               145080.0
# 1          23.19  1750.0        28.99               164038.0
# 2          18.24  1750.0        24.99               187407.0
# 3          16.17  1750.0        22.99               201682.0
# 4          21.89  1750.0        29.99               138109.0
#
#    TotalPurchaseDollars  TotalSalesQuantity  TotalSalesPrice  \
# 0            3811251.60            128606.0        613021.40
# ...

# %% [markdown]
# #=========== Now finally pushing/storing vendors_final_summary table on mysql local server's database 'inventory_db'

# %%
# # THROUGH MYSQLCONNECTOR, CURSOR
# conn = mysql.connector.connect(
#     host='localhost',
#     user='root',
#     password='UMMU@112244',
#     database='inventory_db'
# )


# # ============ cursor (DB object to run mysql queries and fetch data line by line from databale tables as per reqd) ===========
# cursor = conn.cursor()

# %% [markdown]
# ***Creating table and storing vendors_final_summary table in that***

# %%
# vendors_final_summary.dtypes   # get idea column names and datatype
# Out:
# VendorNumber               int64
# VendorName                object
# Brand                      int64
# Description               object
# PurchasePrice            float64
# Volume                   float64
# ActualPrice              float64
# TotalPurchaseQuantity    float64
# TotalPurchaseDollars     float64
# TotalSalesQuantity       float64
# TotalSalesPrice          float64
# TotalSalesDollars        float64
# TotalExciseTax           float64
# FreightCost              float64
# GrossProfit              float64
# ProfitMargin             float64
# StockTurnover            float64
# SalesToPurchaseRatio     float64
# dtype: object

# %%
# query_CT = """CREATE TABLE IF NOT EXISTS vendors_final_summary (
# VendorNumber INT,
# VendorName VARCHAR(100),
# Brand INT,
# Description VARCHAR(100),
# PurchasePrice DECIMAL(10,2),
# Volume DECIMAL(10,1),
# ActualPrice DECIMAL(10,2),
# TotalPurchaseQuantity INT,
# TotalPurchaseDollars DECIMAL(15,2),
# TotalSalesQuantity INT,
# TotalSalesPrice DECIMAL(15,2),
# TotalSalesDollars DECIMAL(15,2),
# TotalExciseTax DECIMAL(15,2),
# FreightCost DECIMAL(15,2),
# GrossProfit DECIMAL(15,2),
# ProfitMargin DECIMAL(15,2),
# StockTurnover DECIMAL(15,2),
# SalesToPurchaseRatio DECIMAL(15,2),

# PRIMARY KEY (VendorNumber, Brand)
# );
# """

# cursor.execute(query_CT)

# %%
# # Now put into this created table 
# with engine.connect() as conn:
#     vendors_final_summary.to_sql('vendors_final_summary', conn , if_exists = 'replace', index= False)  
#     # Like we did while ingesting all tables of vendors database into mysql server database

# %%
# #=== now check again 
# with engine.connect() as conn:
#     vfs = pd.read_sql("SELECT * FROM vendors_final_summary", conn)
#     display(vfs)
# Out:
#        VendorNumber                VendorName  Brand  \
# 0              1128         BROWN-FORMAN CORP   1233
# 1              4425     MARTIGNETTI COMPANIES   3405
# 2             17035         PERNOD RICARD USA   8068
# 3              3960  DIAGEO NORTH AMERICA INC   4261
# 4              3960  DIAGEO NORTH AMERICA INC   3545
# ...             ...                       ...    ...
# 10687          9815            WINE GROUP INC   8527
# 10688          8004            SAZERAC CO INC   5683
# 10689          3924  HEAVEN HILL DISTILLERIES   9123
# 10690          3960  DIAGEO NORTH AMERICA INC   6127
# 10691          7245      PROXIMO SPIRITS INC.   3065
#
#                        Description  PurchasePrice  Volume  ActualPrice  \
# 0          Jack Daniels No 7 Black          26.27  1750.0        36.99
# 1            Tito's Handmade Vodka          23.19  1750.0        28.99
# 2                 Absolut 80 Proof          18.24  1750.0        24.99
# ...

# %% [markdown]
# # **----------------------------------------------------------------------------------------- BOOKMARK ENDS HERE: Retrive, clean and feature engineering of summaru vendors data  -----------------------------------------------------------------------------------------**

# %%
# #==================== RUn script get_vendors_final_summary.py for above task
# %run get_vendors_final_summary.py   # We can schedule this script if we have running data so that nothing manual would be done again & again.
